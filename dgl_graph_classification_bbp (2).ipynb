# %% [markdown]
# i work with bbbp data

# %%
# !pip install dgl
# Out:
# Requirement already satisfied: dgl in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.22.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.10.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.65.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.4)

# %%
# %matplotlib inline
import os

os.environ["DGLBACKEND"] = "pytorch"
import dgl
import numpy as np
import networkx as nx
import torch
import torch.nn as nn
import dgl.function as fn
import torch.nn.functional as F
import shutil
from torch.utils.data import DataLoader
import cloudpickle
from dgl.nn import GraphConv

# %% [markdown]
# #### Set Path

# %%
current_dir = "./"
checkpoint_path = current_dir + "save_models/model_checkpoints/" + "checkpoint"
os.makedirs(checkpoint_path, exist_ok=True)

best_model_path = current_dir + "save_models/best_model/"

folder_data_temp = current_dir +"data_temp/"
shutil.rmtree(folder_data_temp, ignore_errors=True)

path_save = current_dir + "graph_data.zip"
shutil.unpack_archive(path_save, folder_data_temp)

# %% [markdown]
# #### Custom PyTorch Datasets

# %%
""" Classification Dataset """
class DGLDatasetClass(torch.utils.data.Dataset):
    def __init__(self, address):
            self.address=address+".bin"
            self.list_graphs, train_labels_masks_globals = dgl.load_graphs(self.address)
            num_graphs =len(self.list_graphs)
            self.labels = train_labels_masks_globals["labels"].view(num_graphs,-1)
            self.masks = train_labels_masks_globals["masks"].view(num_graphs,-1)
            self.globals = train_labels_masks_globals["globals"].view(num_graphs,-1)
    def __len__(self):
        return len(self.list_graphs)
    def __getitem__(self, idx):
        return  self.list_graphs[idx], self.labels[idx], self.masks[idx], self.globals[idx]

# %% [markdown]
# #### Defining Train, Validation, and Test Set

# %%
path_data_temp = folder_data_temp + "scaffold"+"_"+str(0)
train_set = DGLDatasetClass(address=path_data_temp+"_train")
val_set = DGLDatasetClass(address=path_data_temp+"_val")
test_set = DGLDatasetClass(address=path_data_temp+"_test")

print(len(train_set), len(val_set), len(test_set))
# Out:
# 1631 203 205

# %% [markdown]
# #### Data Loader

# %%
def collate(batch):
    # batch is a list of tuples (graphs, labels, masks, globals)
    # Concatenate a sequence of graphs
    graphs = [e[0] for e in batch]
    g = dgl.batch(graphs)

    # Concatenate a sequence of tensors (labels) along a new dimension
    labels = [e[1] for e in batch]
    labels = torch.stack(labels, 0)

    # Concatenate a sequence of tensors (masks) along a new dimension
    masks = [e[2] for e in batch]
    masks = torch.stack(masks, 0)

    # Concatenate a sequence of tensors (globals) along a new dimension
    globals = [e[3] for e in batch]
    globals = torch.stack(globals, 0)

    return g, labels, masks, globals


def loader(batch_size=64):
    train_dataloader = DataLoader(train_set,
                              batch_size=batch_size,
                              collate_fn=collate,
                              drop_last=False,
                              shuffle=True,
                              num_workers=1)

    val_dataloader =  DataLoader(val_set,
                             batch_size=batch_size,
                             collate_fn=collate,
                             drop_last=False,
                             shuffle=False,
                             num_workers=1)

    test_dataloader = DataLoader(test_set,
                             batch_size=batch_size,
                             collate_fn=collate,
                             drop_last=False,
                             shuffle=False,
                             num_workers=1)
    return train_dataloader, val_dataloader, test_dataloader

# %%
train_dataloader, val_dataloader, test_dataloader = loader(batch_size=64)

# %% [markdown]
# #### Defining A GNN

# %% [markdown]
# ##### Some Variables

# %%
#Bace dataset has 1 task. Some other datasets may have some more number of tasks, e.g., tox21 has 12 tasks.
num_tasks = 1

# Size of global feature of each graph
global_size = 200

# Number of epochs to train the model
num_epochs = 100

# Number of steps to wait if the model performance on the validation set does not improve
patience = 10

#Configurations to instantiate the model
config = {"node_feature_size":127, "edge_feature_size":12, "hidden_size":100}

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size = 200, num_tasks = 1):
        super().__init__()
        self.config = config
        self.num_tasks = num_tasks

        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.conv1 = GraphConv(self.node_feature_size, self.hidden_size,allow_zero_in_degree=True)
        self.conv2 = GraphConv(self.hidden_size, self.num_tasks,allow_zero_in_degree=True)

    # def forward(self, g, in_feat):
    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"]= mol_dgl_graph.ndata["v"][:,:self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:,:self.edge_feature_size]
        h = self.conv1(mol_dgl_graph, mol_dgl_graph.ndata["v"])
        h = F.relu(h)
        h = self.conv2(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %% [markdown]
# #### Function to Compute Score of the Model

# %%
from sklearn.metrics import roc_auc_score

def compute_score(model, data_loader, val_size, num_tasks):
    model.eval()
    metric = roc_auc_score
    with torch.no_grad():
        prediction_all= torch.empty(0)
        labels_all= torch.empty(0)
        masks_all= torch.empty(0)
        for i, (mol_dgl_graph, labels, masks, globals) in enumerate(data_loader):
            prediction = model(mol_dgl_graph, globals)
            prediction = torch.sigmoid(prediction)
            prediction_all = torch.cat((prediction_all, prediction), 0)
            labels_all = torch.cat((labels_all, labels), 0)
            masks_all = torch.cat((masks_all, masks), 0)
        average = torch.tensor([0.])
        for i in range(num_tasks):
            a1 = prediction_all[:, i][masks_all[:,i]==1]
            a2 = labels_all[:, i][masks_all[:,i]==1]
            try:
                t = metric(a2.int().cpu(), a1.cpu()).item()
            except ValueError:
                t = 0
            average += t
    return average.item()/num_tasks

# %% [markdown]
# #### Loss Function

# %%
def loss_func(output, label, mask):
    loss = ((output - label) ** 2) * mask
    loss = torch.sqrt(loss.sum() / mask.sum())
    return loss

# %% [markdown]
# #### Training and Evaluation

# %% [markdown]
# ##### Training Function

# %%
def loss_func(output, label, mask, num_tasks):
    pos_weight = torch.ones((1, num_tasks))
    pos_weight
    criterion = torch.nn.BCEWithLogitsLoss(reduction='none', pos_weight=pos_weight)
    loss = mask*criterion(output,label)
    loss = loss.sum() / mask.sum()
    return loss

# %%
def train_evaluate():

    model = GNN(config, global_size, num_tasks)
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)

    best_val = 0
    patience_count = 1
    epoch = 1

    while epoch <= num_epochs:
        if patience_count <= patience:
            model.train()
            loss_train = train_epoch(train_dataloader, model, optimizer)
            model.eval()
            score_val = compute_score(model, val_dataloader, len(val_set), num_tasks)
            if score_val > best_val:
                best_val = score_val
                print("Save checkpoint")
                path = os.path.join(checkpoint_path, 'checkpoint.pth')
                dict_checkpoint = {"score_val": score_val}
                dict_checkpoint.update({"model_state_dict": model.state_dict(), "optimizer_state": optimizer.state_dict()})
                with open(path, "wb") as outputfile:
                    cloudpickle.dump(dict_checkpoint, outputfile)
                patience_count = 1
            else:
                print("Patience", patience_count)
                patience_count += 1

            print("Epoch: {}/{} | Training Loss: {:.3f} | Valid Score: {:.3f}".format(
            epoch, num_epochs, loss_train, score_val))

            print(" ")
            print("Epoch: {}/{} | Best Valid Score Until Now: {:.3f}".format(epoch, num_epochs, best_val), "\n")
        epoch += 1

    # best model save
    shutil.rmtree(best_model_path, ignore_errors=True)
    shutil.copytree(checkpoint_path, best_model_path)

    print("Final results:")
    print("Average Valid Score: {:.3f}".format(np.mean(best_val)), "\n")

# %% [markdown]
# ##### Function to compute test set score of the final saved model

# %%
def test_evaluate():
    final_model = GNN(config, global_size, num_tasks)
    path = os.path.join(best_model_path, 'checkpoint.pth')
    with open(path, 'rb') as f:
        checkpoint = cloudpickle.load(f)
    final_model.load_state_dict(checkpoint["model_state_dict"])
    final_model.eval()
    test_score = compute_score(final_model, test_dataloader, len(test_set), num_tasks)

    print("Test Score: {:.3f}".format(test_score), "\n")
    print("Execution time: {:.3f} seconds".format(time.time() - start_time))

# %% [markdown]
# ##### Train the model and evaluate its performance

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.631 | Valid Score: 0.391
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.391
#
# Patience 1
# Epoch: 2/100 | Training Loss: 0.610 | Valid Score: 0.355
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.391
#
# Patience 2
# Epoch: 3/100 | Training Loss: 0.598 | Valid Score: 0.345
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.391
#
# Patience 3
# Epoch: 4/100 | Training Loss: 0.590 | Valid Score: 0.351
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.391
#
# Patience 4
# Epoch: 5/100 | Training Loss: 0.584 | Valid Score: 0.362
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.391
#
# Patience 5
# Epoch: 6/100 | Training Loss: 0.580 | Valid Score: 0.376
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.391
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.576 | Valid Score: 0.396
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.396
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.572 | Valid Score: 0.409
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.409
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.569 | Valid Score: 0.435
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.435
#
# Save checkpoint
# Epoch: 10/100 | Training Loss: 0.568 | Valid Score: 0.462
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.462
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.563 | Valid Score: 0.488
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.488
#
# Save checkpoint
# Epoch: 12/100 | Training Loss: 0.561 | Valid Score: 0.511
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.511
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.557 | Valid Score: 0.541
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.541
#
# Save checkpoint
# Epoch: 14/100 | Training Loss: 0.553 | Valid Score: 0.562
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.562
#
# Save checkpoint
# Epoch: 15/100 | Training Loss: 0.551 | Valid Score: 0.581
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.581
#
# Save checkpoint
# Epoch: 16/100 | Training Loss: 0.546 | Valid Score: 0.597
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.597
#
# Save checkpoint
# Epoch: 17/100 | Training Loss: 0.543 | Valid Score: 0.628
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.628
#
# Save checkpoint
# Epoch: 18/100 | Training Loss: 0.540 | Valid Score: 0.640
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.640
#
# Save checkpoint
# Epoch: 19/100 | Training Loss: 0.540 | Valid Score: 0.648
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.648
#
# Save checkpoint
# Epoch: 20/100 | Training Loss: 0.535 | Valid Score: 0.676
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.676
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.532 | Valid Score: 0.695
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.695
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.529 | Valid Score: 0.708
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.708
#
# Save checkpoint
# Epoch: 23/100 | Training Loss: 0.526 | Valid Score: 0.712
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 24/100 | Training Loss: 0.523 | Valid Score: 0.725
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.725
#
# Save checkpoint
# Epoch: 25/100 | Training Loss: 0.521 | Valid Score: 0.729
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.729
#
# Save checkpoint
# Epoch: 26/100 | Training Loss: 0.518 | Valid Score: 0.738
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.738
#
# Save checkpoint
# Epoch: 27/100 | Training Loss: 0.516 | Valid Score: 0.747
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.747
#
# Save checkpoint
# Epoch: 28/100 | Training Loss: 0.511 | Valid Score: 0.754
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.754
#
# Save checkpoint
# Epoch: 29/100 | Training Loss: 0.510 | Valid Score: 0.756
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.756
#
# Save checkpoint
# Epoch: 30/100 | Training Loss: 0.508 | Valid Score: 0.761
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.761
#
# Save checkpoint
# Epoch: 31/100 | Training Loss: 0.504 | Valid Score: 0.763
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.763
#
# Save checkpoint
# Epoch: 32/100 | Training Loss: 0.502 | Valid Score: 0.766
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.766
#
# Save checkpoint
# Epoch: 33/100 | Training Loss: 0.502 | Valid Score: 0.772
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.772
#
# Save checkpoint
# Epoch: 34/100 | Training Loss: 0.496 | Valid Score: 0.774
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.774
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.497 | Valid Score: 0.776
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.776
#
# Save checkpoint
# Epoch: 36/100 | Training Loss: 0.495 | Valid Score: 0.779
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.779
#
# Save checkpoint
# Epoch: 37/100 | Training Loss: 0.490 | Valid Score: 0.783
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.783
#
# Save checkpoint
# Epoch: 38/100 | Training Loss: 0.492 | Valid Score: 0.784
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.784
#
# Save checkpoint
# Epoch: 39/100 | Training Loss: 0.489 | Valid Score: 0.787
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.787
#
# Save checkpoint
# Epoch: 40/100 | Training Loss: 0.486 | Valid Score: 0.788
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.788
#
# Save checkpoint
# Epoch: 41/100 | Training Loss: 0.483 | Valid Score: 0.789
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.789
#
# Save checkpoint
# Epoch: 42/100 | Training Loss: 0.483 | Valid Score: 0.793
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.793
#
# Save checkpoint
# Epoch: 43/100 | Training Loss: 0.479 | Valid Score: 0.793
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.793
#
# Save checkpoint
# Epoch: 44/100 | Training Loss: 0.480 | Valid Score: 0.797
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.797
#
# Save checkpoint
# Epoch: 45/100 | Training Loss: 0.479 | Valid Score: 0.797
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.797
#
# Save checkpoint
# Epoch: 46/100 | Training Loss: 0.472 | Valid Score: 0.799
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.799
#
# Patience 1
# Epoch: 47/100 | Training Loss: 0.474 | Valid Score: 0.798
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.799
#
# Save checkpoint
# Epoch: 48/100 | Training Loss: 0.474 | Valid Score: 0.800
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.800
#
# Save checkpoint
# Epoch: 49/100 | Training Loss: 0.473 | Valid Score: 0.802
#
# Epoch: 49/100 | Best Valid Score Until Now: 0.802
#
# Patience 1
# Epoch: 50/100 | Training Loss: 0.473 | Valid Score: 0.801
#
# Epoch: 50/100 | Best Valid Score Until Now: 0.802
#
# Patience 2
# Epoch: 51/100 | Training Loss: 0.466 | Valid Score: 0.801
#
# Epoch: 51/100 | Best Valid Score Until Now: 0.802
#
# Patience 3
# Epoch: 52/100 | Training Loss: 0.468 | Valid Score: 0.801
#
# Epoch: 52/100 | Best Valid Score Until Now: 0.802
#
# Save checkpoint
# Epoch: 53/100 | Training Loss: 0.467 | Valid Score: 0.803
#
# Epoch: 53/100 | Best Valid Score Until Now: 0.803
#
# Save checkpoint
# Epoch: 54/100 | Training Loss: 0.467 | Valid Score: 0.804
#
# Epoch: 54/100 | Best Valid Score Until Now: 0.804
#
# Patience 1
# Epoch: 55/100 | Training Loss: 0.463 | Valid Score: 0.803
#
# Epoch: 55/100 | Best Valid Score Until Now: 0.804
#
# Save checkpoint
# Epoch: 56/100 | Training Loss: 0.465 | Valid Score: 0.805
#
# Epoch: 56/100 | Best Valid Score Until Now: 0.805
#
# Save checkpoint
# Epoch: 57/100 | Training Loss: 0.461 | Valid Score: 0.806
#
# Epoch: 57/100 | Best Valid Score Until Now: 0.806
#
# Save checkpoint
# Epoch: 58/100 | Training Loss: 0.457 | Valid Score: 0.807
#
# Epoch: 58/100 | Best Valid Score Until Now: 0.807
#
# Patience 1
# Epoch: 59/100 | Training Loss: 0.461 | Valid Score: 0.806
#
# Epoch: 59/100 | Best Valid Score Until Now: 0.807
#
# Patience 2
# Epoch: 60/100 | Training Loss: 0.458 | Valid Score: 0.806
#
# Epoch: 60/100 | Best Valid Score Until Now: 0.807
#
# Patience 3
# Epoch: 61/100 | Training Loss: 0.459 | Valid Score: 0.807
#
# Epoch: 61/100 | Best Valid Score Until Now: 0.807
#
# Save checkpoint
# Epoch: 62/100 | Training Loss: 0.453 | Valid Score: 0.808
#
# Epoch: 62/100 | Best Valid Score Until Now: 0.808
#
# Patience 1
# Epoch: 63/100 | Training Loss: 0.453 | Valid Score: 0.808
#
# Epoch: 63/100 | Best Valid Score Until Now: 0.808
#
# Patience 2
# Epoch: 64/100 | Training Loss: 0.454 | Valid Score: 0.808
#
# Epoch: 64/100 | Best Valid Score Until Now: 0.808
#
# Patience 3
# Epoch: 65/100 | Training Loss: 0.452 | Valid Score: 0.808
#
# Epoch: 65/100 | Best Valid Score Until Now: 0.808
#
# Save checkpoint
# Epoch: 66/100 | Training Loss: 0.453 | Valid Score: 0.809
#
# Epoch: 66/100 | Best Valid Score Until Now: 0.809
#
# Save checkpoint
# Epoch: 67/100 | Training Loss: 0.449 | Valid Score: 0.809
#
# Epoch: 67/100 | Best Valid Score Until Now: 0.809
#
# Patience 1
# Epoch: 68/100 | Training Loss: 0.451 | Valid Score: 0.809
#
# Epoch: 68/100 | Best Valid Score Until Now: 0.809
#
# Save checkpoint
# Epoch: 69/100 | Training Loss: 0.451 | Valid Score: 0.810
#
# Epoch: 69/100 | Best Valid Score Until Now: 0.810
#
# Save checkpoint
# Epoch: 70/100 | Training Loss: 0.447 | Valid Score: 0.810
#
# Epoch: 70/100 | Best Valid Score Until Now: 0.810
#
# Patience 1
# Epoch: 71/100 | Training Loss: 0.445 | Valid Score: 0.810
#
# Epoch: 71/100 | Best Valid Score Until Now: 0.810
#
# Save checkpoint
# Epoch: 72/100 | Training Loss: 0.446 | Valid Score: 0.811
#
# Epoch: 72/100 | Best Valid Score Until Now: 0.811
#
# Save checkpoint
# Epoch: 73/100 | Training Loss: 0.444 | Valid Score: 0.812
#
# Epoch: 73/100 | Best Valid Score Until Now: 0.812
#
# Save checkpoint
# Epoch: 74/100 | Training Loss: 0.449 | Valid Score: 0.812
#
# Epoch: 74/100 | Best Valid Score Until Now: 0.812
#
# Save checkpoint
# Epoch: 75/100 | Training Loss: 0.444 | Valid Score: 0.813
#
# Epoch: 75/100 | Best Valid Score Until Now: 0.813
#
# Save checkpoint
# Epoch: 76/100 | Training Loss: 0.446 | Valid Score: 0.814
#
# Epoch: 76/100 | Best Valid Score Until Now: 0.814
#
# Save checkpoint
# Epoch: 77/100 | Training Loss: 0.443 | Valid Score: 0.815
#
# Epoch: 77/100 | Best Valid Score Until Now: 0.815
#
# Patience 1
# Epoch: 78/100 | Training Loss: 0.445 | Valid Score: 0.815
#
# Epoch: 78/100 | Best Valid Score Until Now: 0.815
#
# Save checkpoint
# Epoch: 79/100 | Training Loss: 0.441 | Valid Score: 0.816
#
# Epoch: 79/100 | Best Valid Score Until Now: 0.816
#
# Save checkpoint
# Epoch: 80/100 | Training Loss: 0.441 | Valid Score: 0.817
#
# Epoch: 80/100 | Best Valid Score Until Now: 0.817
#
# Patience 1
# Epoch: 81/100 | Training Loss: 0.442 | Valid Score: 0.816
#
# Epoch: 81/100 | Best Valid Score Until Now: 0.817
#
# Patience 2
# Epoch: 82/100 | Training Loss: 0.439 | Valid Score: 0.817
#
# Epoch: 82/100 | Best Valid Score Until Now: 0.817
#
# Save checkpoint
# Epoch: 83/100 | Training Loss: 0.438 | Valid Score: 0.817
#
# Epoch: 83/100 | Best Valid Score Until Now: 0.817
#
# Patience 1
# Epoch: 84/100 | Training Loss: 0.439 | Valid Score: 0.817
#
# Epoch: 84/100 | Best Valid Score Until Now: 0.817
#
# Patience 2
# Epoch: 85/100 | Training Loss: 0.435 | Valid Score: 0.817
#
# Epoch: 85/100 | Best Valid Score Until Now: 0.817
#
# Patience 3
# Epoch: 86/100 | Training Loss: 0.440 | Valid Score: 0.817
#
# Epoch: 86/100 | Best Valid Score Until Now: 0.817
#
# Save checkpoint
# Epoch: 87/100 | Training Loss: 0.436 | Valid Score: 0.818
#
# Epoch: 87/100 | Best Valid Score Until Now: 0.818
#
# Save checkpoint
# Epoch: 88/100 | Training Loss: 0.437 | Valid Score: 0.818
#
# Epoch: 88/100 | Best Valid Score Until Now: 0.818
#
# Patience 1
# Epoch: 89/100 | Training Loss: 0.439 | Valid Score: 0.818
#
# Epoch: 89/100 | Best Valid Score Until Now: 0.818
#
# Patience 2
# Epoch: 90/100 | Training Loss: 0.434 | Valid Score: 0.818
#
# Epoch: 90/100 | Best Valid Score Until Now: 0.818
#
# Patience 3
# Epoch: 91/100 | Training Loss: 0.434 | Valid Score: 0.818
#
# Epoch: 91/100 | Best Valid Score Until Now: 0.818
#
# Patience 4
# Epoch: 92/100 | Training Loss: 0.433 | Valid Score: 0.818
#
# Epoch: 92/100 | Best Valid Score Until Now: 0.818
#
# Patience 5
# Epoch: 93/100 | Training Loss: 0.432 | Valid Score: 0.818
#
# Epoch: 93/100 | Best Valid Score Until Now: 0.818
#
# Patience 6
# Epoch: 94/100 | Training Loss: 0.434 | Valid Score: 0.818
#
# Epoch: 94/100 | Best Valid Score Until Now: 0.818
#
# Save checkpoint
# Epoch: 95/100 | Training Loss: 0.433 | Valid Score: 0.819
#
# Epoch: 95/100 | Best Valid Score Until Now: 0.819
#
# Patience 1
# Epoch: 96/100 | Training Loss: 0.433 | Valid Score: 0.819
#
# Epoch: 96/100 | Best Valid Score Until Now: 0.819
#
# Patience 2
# Epoch: 97/100 | Training Loss: 0.429 | Valid Score: 0.819
#
# Epoch: 97/100 | Best Valid Score Until Now: 0.819
#
# Patience 3
# Epoch: 98/100 | Training Loss: 0.432 | Valid Score: 0.818
#
# Epoch: 98/100 | Best Valid Score Until Now: 0.819
#
# Patience 4
# Epoch: 99/100 | Training Loss: 0.431 | Valid Score: 0.818
#
# Epoch: 99/100 | Best Valid Score Until Now: 0.819
#
# Patience 5
# Epoch: 100/100 | Training Loss: 0.430 | Valid Score: 0.819
#
# Epoch: 100/100 | Best Valid Score Until Now: 0.819
#
# Final results:
# Average Valid Score: 0.819
#
# Test Score: 0.623
#
# Execution time: 55.949 seconds
